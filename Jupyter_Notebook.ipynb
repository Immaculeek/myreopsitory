# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
This notebook demonstrates basic concepts in data science, including languages, libraries, tools, and simple arithmetic operations.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Scikit-learn
# - TensorFlow
# - ggplot2

# %% [markdown]
# ## Data Science Tools
# | Tool          | Purpose                   |
# |---------------|---------------------------|
# | Jupyter       | Interactive Computing     |
# | RStudio       | Statistical Analysis      |
# | Apache Spark  | Big Data Processing       |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are examples of simple arithmetic expressions in Python.

# %%
# Multiplication and addition example
result = (3 * 4) + 5
print("The result is:", result)

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
# - Understand data science languages and libraries.
# - Explore popular data science tools.
# - Perform basic arithmetic operations.
# - Learn how to share notebooks via GitHub.

# %% [markdown]
# ## Author
# Immaculee Katounke
